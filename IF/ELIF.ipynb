# %% [markdown]
# <a href="https://colab.research.google.com/github/Zulfi1214/python-first-task/blob/main/IF/ELIF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from re import I
stored_email ="ali@gmail.com"
stored_password="1234"
email=input("enter your email : ")
password=(input("enter your password : "))
if email ==stored_email and password == stored_password:
   print("wellcom")
elif email ==stored_email and password != stored_password:
  print("incorrect password")
  password=input("enter your password again : ")
  if password == stored_password:
      print("wellcom")
  else:
      print("beta tum sy nahe hoga")
elif email !=stored_email and password == stored_password:
      print("incorrect email")
      email=input("enter your email again : ")
      if email ==stored_email:
          print("wellcom")
      else:
          print("beta tum sy nahe hoga")

else:
      print("invalid")
# Out:
# enter your email : sa
# enter your password : 1234
# incorrect email
# enter your email again : ali@gmail.com
# wellcom
